# %% [markdown]
# # 13 Theorem 2 Positive: Artifact Learning
#
# Filtered artefacts become easier to imitate for downstream learners.

# %%
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == 'active':
    ROOT = ROOT.parents[2]
OUT = ROOT / 'GitHub/data/outputs/theorem2_positive'
OUT.mkdir(parents=True, exist_ok=True)
OUT
