# %% [markdown]
# # 16 Arithmetic: Full Trace vs Final Answer
#
# Compare agents trained on full arithmetic traces versus final-answer-only corpora.

# %%
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == 'active':
    ROOT = ROOT.parents[2]
OUT = ROOT / 'GitHub/data/outputs/theorem2_negative_arithmetic'
OUT.mkdir(parents=True, exist_ok=True)
OUT
