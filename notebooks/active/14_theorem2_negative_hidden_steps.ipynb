# %% [markdown]
# # 14 Theorem 2 Negative: Hidden Steps
#
# Omitted intermediate traces can damage process-learning tasks.

# %%
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == 'active':
    ROOT = ROOT.parents[2]
OUT = ROOT / 'GitHub/data/outputs/theorem2_negative'
OUT.mkdir(parents=True, exist_ok=True)
OUT
