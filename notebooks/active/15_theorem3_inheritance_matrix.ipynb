# %% [markdown]
# # 15 Theorem 3 Inheritance Matrix
#
# Track inheritance of both gains and losses across environments.

# %%
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == 'active':
    ROOT = ROOT.parents[2]
OUT = ROOT / 'GitHub/data/outputs/theorem3_inheritance'
OUT.mkdir(parents=True, exist_ok=True)
OUT
