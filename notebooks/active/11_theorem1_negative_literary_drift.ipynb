# %% [markdown]
# # 11 Theorem 1 Negative: Literary Drift
#
# Rare-form thinning and minority-style loss under recursive resampling.

# %%
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == 'active':
    ROOT = ROOT.parents[2]
OUT = ROOT / 'GitHub/data/outputs/theorem1_negative'
OUT.mkdir(parents=True, exist_ok=True)
OUT
