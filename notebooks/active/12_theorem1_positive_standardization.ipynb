# %% [markdown]
# # 12 Theorem 1 Positive: Standardization
#
# Error-correction and normalization under recursive resampling.

# %%
from pathlib import Path
ROOT = Path.cwd().resolve()
if ROOT.name == 'active':
    ROOT = ROOT.parents[2]
OUT = ROOT / 'GitHub/data/outputs/theorem1_positive'
OUT.mkdir(parents=True, exist_ok=True)
OUT
